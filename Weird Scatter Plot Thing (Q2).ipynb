# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('data/tennis.csv')
df
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  1998-10-05   WS   Indoor: Hard
# 1     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 2     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 3     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  1998-08-24   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  2012-01-16   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# 0      Draw: 32          1        396.0                 $9,800   R32  ...
# 1      Draw: 32         59        878.0                $10,800   R32  ...
# 2      Draw: 32         59        878.0                $10,800   R16  ...
# 3      Draw: 32         59        878.0                $10,800     Q  ...
# 4      Draw: 32          1        680.0                   $520   R32  ...
# ...         ...        ...          ...                    ...   ...  ...
# 1174  Draw: 128        720          3.0              A$437,000     S  ...
# 1175   Draw: 32         90          3.0                $50,030   R32  ...
# 1176   Draw: 32         90          3.0                $50,030   R16  ...
# 1177   Draw: 32         90          3.0                $50,030     Q  ...
# 1178   Draw: 32         90          3.0                $50,030     S  ...
#
#      player2 break points converted won player2 break points converted total  \
# 0                                   4.0                                  8.0
# 1                                   0.0                                  1.0
# 2                                   0.0                                  4.0
# 3                                   3.0                                 10.0
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 1174                                6.0                                 16.0
# 1175                                0.0                                  0.0
# 1176                                0.0                                  2.0
# 1177                                4.0                                  9.0
# 1178                                NaN                                  NaN
#
#      player2 return games played player2 total service points won  \
# 0                            8.0                             36.0
# 1                            8.0                             33.0
# 2                           10.0                             46.0
# 3                           10.0                             44.0
# 4                            NaN                              NaN
# ...                          ...                              ...
# 1174                        21.0                             95.0
# 1175                         8.0                             22.0
# 1176                         9.0                             28.0
# 1177                        16.0                             47.0
# 1178                         NaN                              NaN
#
#      player2 total service points total player2 total return points won  \
# 0                                  50.0                            26.0
# 1                                  65.0                             8.0
# 2                                  75.0                            23.0
# 3                                  63.0                            26.0
# 4                                   NaN                             NaN
# ...                                 ...                             ...
# 1174                              141.0                            51.0
# 1175                               45.0                             9.0
# 1176                               50.0                            11.0
# 1177                               78.0                            34.0
# 1178                                NaN                             NaN
#
#       player2 total return points total player2 total points won  \
# 0                                  53.0                     62.0
# 1                                  41.0                     41.0
# 2                                  73.0                     69.0
# 3                                  67.0                     70.0
# 4                                   NaN                      NaN
# ...                                 ...                      ...
# 1174                              135.0                    146.0
# 1175                               41.0                     31.0
# 1176                               49.0                     39.0
# 1177                               95.0                     81.0
# 1178                                NaN                      NaN
#
#      player2 total points total    win
# 0                         103.0  False
# 1                         106.0   True
# 2                         148.0   True
# 3                         130.0  False
# 4                           NaN  False
# ...                         ...    ...
# 1174                      276.0  False
# 1175                       86.0   True
# 1176                       99.0   True
# 1177                      173.0   True
# 1178                        NaN  False
#
# [1179 rows x 71 columns]

# %%
df['dftpt'] = df['player1 double faults'] / df['player1 total points total']
df
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  1998-10-05   WS   Indoor: Hard
# 1     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 2     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 3     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  1998-08-24   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  2012-01-16   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# 0      Draw: 32          1        396.0                 $9,800   R32  ...
# 1      Draw: 32         59        878.0                $10,800   R32  ...
# 2      Draw: 32         59        878.0                $10,800   R16  ...
# 3      Draw: 32         59        878.0                $10,800     Q  ...
# 4      Draw: 32          1        680.0                   $520   R32  ...
# ...         ...        ...          ...                    ...   ...  ...
# 1174  Draw: 128        720          3.0              A$437,000     S  ...
# 1175   Draw: 32         90          3.0                $50,030   R32  ...
# 1176   Draw: 32         90          3.0                $50,030   R16  ...
# 1177   Draw: 32         90          3.0                $50,030     Q  ...
# 1178   Draw: 32         90          3.0                $50,030     S  ...
#
#      player2 break points converted total player2 return games played  \
# 0                                     8.0                         8.0
# 1                                     1.0                         8.0
# 2                                     4.0                        10.0
# 3                                    10.0                        10.0
# 4                                     NaN                         NaN
# ...                                   ...                         ...
# 1174                                 16.0                        21.0
# 1175                                  0.0                         8.0
# 1176                                  2.0                         9.0
# 1177                                  9.0                        16.0
# 1178                                  NaN                         NaN
#
#      player2 total service points won player2 total service points total  \
# 0                                36.0                               50.0
# 1                                33.0                               65.0
# 2                                46.0                               75.0
# 3                                44.0                               63.0
# 4                                 NaN                                NaN
# ...                               ...                                ...
# 1174                             95.0                              141.0
# 1175                             22.0                               45.0
# 1176                             28.0                               50.0
# 1177                             47.0                               78.0
# 1178                              NaN                                NaN
#
#      player2 total return points won player2 total return points total  \
# 0                               26.0                              53.0
# 1                                8.0                              41.0
# 2                               23.0                              73.0
# 3                               26.0                              67.0
# 4                                NaN                               NaN
# ...                              ...                               ...
# 1174                            51.0                             135.0
# 1175                             9.0                              41.0
# 1176                            11.0                              49.0
# 1177                            34.0                              95.0
# 1178                             NaN                               NaN
#
#       player2 total points won player2 total points total    win     dftpt
# 0                         62.0                      103.0  False  0.019417
# 1                         41.0                      106.0   True  0.000000
# 2                         69.0                      148.0   True  0.020270
# 3                         70.0                      130.0  False  0.046154
# 4                          NaN                        NaN  False       NaN
# ...                        ...                        ...    ...       ...
# 1174                     146.0                      276.0  False  0.018116
# 1175                      31.0                       86.0   True  0.000000
# 1176                      39.0                       99.0   True  0.000000
# 1177                      81.0                      173.0   True  0.011561
# 1178                       NaN                        NaN  False       NaN
#
# [1179 rows x 72 columns]

# %%
year_start = df.groupby('year')['start date'].max()
year_start
# Out:
# year
# 1998    1998-10-05
# 1999    1999-10-25
# 2000    2000-11-20
# 2001    2001-10-29
# 2002    2002-11-11
# 2003    2003-11-10
# 2004    2004-11-15
# 2005    2005-11-14
# 2006    2006-11-13
# 2007    2007-11-12
# 2008    2008-11-09
# 2009    2009-11-22
# 2010    2010-11-21
# 2011    2011-11-20
# 2012    2012-11-05
# Name: start date, dtype: object

# %%
year_ratio = df.groupby('year')['dftpt'].mean()
year_ratio
# Out:
# year
# 1998    0.021580
# 1999    0.023588
# 2000    0.021473
# 2001    0.017495
# 2002    0.016521
# 2003    0.018611
# 2004    0.013195
# 2005    0.010575
# 2006    0.007639
# 2007    0.007388
# 2008    0.005887
# 2009    0.010379
# 2010    0.009185
# 2011    0.009136
# 2012    0.009365
# Name: dftpt, dtype: float64

# %%
fig, ax = plt.subplots()
ax.plot_date(pd.to_datetime(df['start date']), df['dftpt'], alpha = 0.5)
ax.plot_date(pd.to_datetime(year_start), year_ratio, '-', lw = 5)
plt.xlabel('Year')
plt.ylabel('Double fault ratio')
# Out:
# Text(0, 0.5, 'Double fault ratio')
